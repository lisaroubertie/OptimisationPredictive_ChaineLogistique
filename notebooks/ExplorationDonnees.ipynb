# %% [markdown]
# Exploration de données

# %% [markdown]
# Ce notebook a pour objectif d'explorer le dataset M5 afin de comprendre la structure des données, identifier des patterns, détecter d'éventuelles anomalies et préparer les futures étapes de modélisation.

# %%
import pandas as pd

df = pd.read_csv("/lisaroubertie/Desktop/Cours/Inge2/S2/ProjetApplication/OptimisationPredictive_ChaineLogistique/datas/sales_train_evaluation.csv")
df.head
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_csv("/lisaroubertie/Desktop/Cours/Inge2/S2/ProjetApplication/OptimisationPredictive_ChaineLogistique/datas/sales_train_evaluation.csv")
#       4 df.head
#
# ModuleNotFoundError: No module named 'pandas'
